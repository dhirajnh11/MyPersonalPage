# %% [markdown]
# <a href="https://colab.research.google.com/github/dhirajnh11/MyPersonalPage/blob/main/00_IntroToPyForGenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# All common code in next few cells

# %%
# %%writefile winner.py
# write all common code in a few cells - cell1
# Out:
# Overwriting winner.py

# %%
# %%writefile -a winner.py
# write all common code in a few cells - cell2
# Out:
# Appending to winner.py

# %% [markdown]
# Experiment 1 with KVP

# %%
# Experiment 1 code here

# %% [markdown]
# Experiment 2 with OCR

# %%
# %%writefile -a winner.py
# experiment 2 code here
# Out:
# Appending to winner.py

# %% [markdown]
# Now let's compare the 2

# %%
# new evaluation code for the 2 experiments here

# Just assumption-> Experiment 2 wins!

# %% [markdown]
# Data Structures we must know!

# %% [markdown]
# Lists- most common
#
# Represented by [ ]

# %%
# Array and Linked List and Trees

# Python is precompiled C and C++

# Python data structures are JUST POINTER MANIPULATION!
# Size perspective-> pointer to int, char, function-> they are all of the same size!

mylist = [42, "hello world", 'a single quote', 3.14, 42, False, True, 1, 0]
mylist2 = [mylist, mylist, 3]

# %%
mylist
# Out:
# [42, 'hello world', 'a single quote', 3.14, 42, False, True, 1, 0]

# %%
mylist2
# Out:
# [[102, 'hello world', 'a single quote', 3.14, 42, False, True, 1, 0],
#  [102, 'hello world', 'a single quote', 3.14, 42, False, True, 1, 0],
#  3]

# %%
mylist[0] = 102
mylist
# Out:
# [102, 'hello world', 'a single quote', 3.14, 42, False, True, 1, 0]

# %%
mylist2
# Out:
# [[42, 'hello world', 'a single quote', 3.14, 42, False, True, 1, 0],
#  [42, 'hello world', 'a single quote', 3.14, 42, False, True, 1, 0],
#  3]

# %% [markdown]
# Lists are MUTABLE, EDITABLE, INDEXABLE, ORDERED

# %% [markdown]
# Next data structure-> Tuple
#
# tuple is like a list, but READONLY (no mutations, edit)
#
# Represented by ( )

# %%
myTup = (1, 2, mylist, False, False, True)

# %%
myTup
# Out:
# (1,
#  2,
#  [42, 'hello world', 'a single quote', 3.14, 42, False, True, 1, 0],
#  False,
#  False,
#  True)

# %%
# we should get an error because Tuple is uneditable
myTup[0] = 42
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_887/518708737.py in <cell line: 0>()
#       1 # we should get an error because Tuple is uneditable
# ----> 2 myTup[0] = 42
#
# TypeError: 'tuple' object does not support item assignment

# %%
#indexable
myTup[1]
# Out:
# 2

# %%
# negative indexing
# positive index-> left to right
# neg index -> right to left

myTup [-1] # LAST ELEMENT
# Out:
# True

# %%
myTup[-2], myTup[-3]
# Out:
# (False, False)

# %%
# works on all both structures (list and tuple)
mylist[-2] = 'hello world'

# %%
myTup
# Out:
# (1,
#  2,
#  [42,
#   'hello world',
#   'a single quote',
#   3.14,
#   42,
#   False,
#   True,
#   'hello world',
#   0],
#  False,
#  False,
#  True)

# %% [markdown]
# SET -> exactly the same as set theory
#
# Represented by { }

# %%
myset = { 42, 42, 'blah', False, 1, True, 'bye bye'}
myset
# Out:
# {1, 42, False, 'blah', 'bye bye'}

# %% [markdown]
# SETS ARE UNORDERED, UNINDEXABLE

# %%
# error expected
myset[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_887/3063551153.py in <cell line: 0>()
#       1 # error expected
# ----> 2 myset[2]
#
# TypeError: 'set' object is not subscriptable

# %%
myset1 = { 42, 42, 'blah', False, 0, 1, True, 'bye bye'}
myset2 = { 'pika pika'}
myset1.union( myset2) # UNION of 2 sets
# Out:
# {1, 42, False, 'blah', 'bye bye', 'pika pika'}

# %%
# You can open literally ANYTHING in python as a folder

dir(myset1)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %% [markdown]
# Dictionary
#
# is a SET of Key-Value pairs!
#
# As it is a SET, there is no ORDER
# BUT there is INDEX -> in form of keys!

# %%
namelist = ['pikachu', 'john', 'mary']
agelist = [10, 20, 5]
mydataset = {
    "name" : namelist,
    "age" :agelist
}
# dictionaries can represent an entire dataset like this! (Excel, JSON, XML, SQL)

# %%
mydataset
# Out:
# {'name': ['pikachu', 'john', 'mary'], 'age': [10, 20, 5]}

# %%
mydataset["name"]
# Out:
# ['pikachu', 'john', 'mary']

# %%
mydataset[False] = 3.14

# %%
mydataset
# Out:
# {'name': ['pikachu', 'john', 'mary'], 'age': [10, 20, 5], False: 3.14}

# %%
mydataset[0] = 'any random thing'

# %%
mydataset
# Out:
# {'name': ['pikachu', 'john', 'mary'],
#  'age': [10, 20, 5],
#  False: 'any random thing'}

# %%
mydataset['blah'] = {1:0, 0:1}

# %%
mydataset
# Out:
# {'name': ['pikachu', 'john', 'mary'],
#  'age': [10, 20, 5],
#  False: 'any random thing',
#  'blah': {1: 0, 0: 1}}

# %%
mydataset['blah'][1]
# Out:
# 0

# %%
mydataset[3.14] = 'apple pi'

# %%
mydataset
# Out:
# {'name': ['pikachu', 'john', 'mary'],
#  'age': [10, 20, 5],
#  False: 'any random thing',
#  'blah': {1: 0, 0: 1},
#  3.14: 'apple pi'}

# %% [markdown]
# List Comprehension

# %%
age = [10, 20, 30 , 40]
print('old values')
print(age)
# objective is to double them up

# traditional way
counter = 0
for a in age:
  newval = a * 2
  age[counter] = newval
  counter = counter + 1

print('new age')
print(age)
# Out:
# old values
# [10, 20, 30, 40]
# new age
# [20, 40, 60, 80]

# %%
age = [10, 20, 30 , 40]
print('old values')
print(age)
# objective is to double them up

# list comprehension way
age = [ a*2 for a in age]

print('new age')
print(age)
# Out:
# old values
# [10, 20, 30, 40]
# new age
# [20, 40, 60, 80]

# %%
# dictionary comprehension is also possible

sample_dictionary = { "kids": "policy 1", "adults": "policy 2"}

# you wanted to reverse the structure, and map policies to age group instead

sample_dictionary = { value:key for key,value in sample_dictionary.items() }

sample_dictionary
# Out:
# {'policy 1': 'kids', 'policy 2': 'adults'}
